# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.abspath('../src'))

from supplier_overview_table import summarize_supplier_delivery
from IPython.display import display
import pandas as pd

summarize_supplier_delivery(
    delivery_csv_path='../data/4.supplier_overview.csv',
    supplier_master_csv_path='../data/1.supplier_master_dataset.csv',
    output_csv_path='../data/7.supplier_delivery_table.csv'
)
summary = pd.read_csv('../data/7.supplier_delivery_table.csv')
display(summary.reset_index(drop=True).style.hide(axis='index'))
# Out:
# supplier_delivery saved to ../data/7.supplier_delivery_table.csv
# <style type="text/css">
# </style>
# <table id="T_01f61">
#   <thead>
#     <tr>
#       <th id="T_01f61_level0_col0" class="col_heading level0 col0" >Supplier ID</th>
#       <th id="T_01f61_level0_col1" class="col_heading level0 col1" >Supplier Name</th>
#       <th id="T_01f61_level0_col2" class="col_heading level0 col2" >Value Category</th>
#       <th id="T_01f61_level0_col3" class="col_heading level0 col3" >%_on_time</th>
#       <th id="T_01f61_level0_col4" class="col_heading level0 col4" >%_delayed</th>
#       <th id="T_01f61_level0_col5" class="col_heading level0 col5" >avg_delay</th>
#       <th id="T_01f61_level0_col6" class="col_heading level0 col6" >avg_shipment_volume</th>
#       <th id="T_01f61_level0_col7" class="col_heading level0 col7" >%_shipment_lost</th>
#       <th id="T_01f61_level0_col8" class="col_heading level0 col8" >%_defect_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
